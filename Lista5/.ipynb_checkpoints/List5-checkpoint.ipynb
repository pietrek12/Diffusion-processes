# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
import imageio
import random

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### a)

# %%
def sir_model(N, beta, r, steps, dt = 1):
    S0 = N - 1
    I0 = 1
    R0 = 0
    S, I, R = [S0], [I0], [R0]
    for i in range(int(steps/dt) - 1):
        S.append(S[i] - (beta*S[i]*I[i]/N)*dt)
        I.append(I[i] + (beta*S[i]*I[i]/N - r*I[i])*dt)
        R.append(R[i] + (r*I[i])*dt)
    return S, I, R

# %% [markdown]
# I took population of 10000 people.

# %%
N = 10000

# %% [markdown]
# Firstly I took $\beta N = 0.5$ and $r = 0.2$ so that $\frac{\beta N}{r} > 1$

# %%
beta = 0.5
r = 0.2
X = sir_model(N, beta, r, 100)

# %%
plt.figure(figsize = (16, 9), dpi = 150)
plt.grid()
plt.plot(X[0])
plt.plot(X[1])
plt.plot(X[2])
plt.legend(["S: susceptible", "I: infected", "R: removed"])
plt.show()

# %% [markdown]
# As we can see there was an epidemic. Now I will take $\beta N = 0.1$ and $r = 0.2$ so that $\frac{\beta N}{r} <1 $

# %%
beta = 0.1
r = 0.2
X1 = sir_model(N, beta, r, 100)

# %%
plt.figure(figsize = (16, 9), dpi = 150)
plt.grid()
plt.plot(X1[0])
plt.plot(X1[1])
plt.plot(X1[2])
plt.legend(["S: susceptible", "I: infected", "R: removed"])
plt.show()

# %% [markdown]
# As we can see there is no epidemic. We can also see how will look like plot of infected in time

# %%
plt.figure(figsize = (16, 9), dpi = 150)
plt.grid()
plt.plot(X1[1], color = "orange")
plt.legend(["I: infected"])
plt.show()

# %% [markdown]
# Let us see what happens when $R_0$ is close to $1$. This time I took $\beta = 0.5$ and $r = 0.45$

# %%
beta = 0.5
r = 0.45
X2 = sir_model(N, beta, r, 300)

# %%
plt.figure(figsize = (16, 9), dpi = 150)
plt.grid()
plt.plot(X2[0])
plt.plot(X2[1])
plt.plot(X2[2])
plt.legend(["S: susceptible", "I: infected", "R: removed"])
plt.show()

# %% [markdown]
# As we can see, there was epidemic but small one.

# %% [markdown]
# ### b)

# %% [markdown]
# Let us se what does phase portrait looks like for $\beta N = 0.5$ and $r = 0.2$ so $R_0 > 1$ (epidemic). $N = 10000$.

# %%
N = 10000
beta = 0.5
r = 0.2

# %%
def f(Y):
    S, I = Y
    return [-beta*S*I/N, beta*S*I/N - r*I]

def phase_portrait(beta, r, N):
    S = np.linspace(0, N, 30)
    S = S[::-1]
    I = np.linspace(0, N, 30)
    Y1, Y2 = np.meshgrid(S, I)

    u, v = np.zeros(Y1.shape), np.zeros(Y2.shape)

    NI, NJ = Y1.shape

    for i in range(NI):
        for j in range(NJ):
            x = Y1[i, j]
            y = Y2[i, j]
            yprime = f([x, y])
            u[i,j] = yprime[0]
            v[i,j] = yprime[1]

    plt.figure(figsize = (16, 9), dpi = 150)
    Q = plt.quiver(Y1, Y2, u, v)

    plt.xlabel("S: susceptible")
    plt.ylabel("I: infected")
    plt.xlim([-0, N])
    plt.ylim([-0, N])
    plt.show()

# %%
phase_portrait(beta, r, N)

# %% [markdown]
# What about portrait for nonepidemic case? Now $\beta N = 0.2$ and $r = 0.5$ so $R_0 < 1$.

# %%
N = 10000
beta = 0.2
r = 0.5
phase_portrait(beta, r, N)

# %% [markdown]
# ### c)

# %%
def total_infected_for_beta(beta, r, N):
    R = len(r)
    R0 = beta/r
    Is = np.empty(R)
    for i in range(R):
        steps = 100
        I = sir_model(N, beta, r[i], steps, dt = 1)[1]
        if not int(I[-1]) == 0:
            steps = steps*2
            continue
        Is[i] = sum(I)
    return R0, Is

# %%
N = 10000
beta = 1
r = np.linspace(0.1, 2, 1000)

# %%
X = total_infected_for_beta(beta, r, N)

# %%
plt.figure(figsize = (16, 9), dpi = 150)
plt.plot(X[0], X[1])
plt.xlabel("R0")
plt.ylabel("Sum of Infected")
plt.show()

# %%
def total_infected_for_r(beta, r, N):
    B = len(beta)
    R0 = beta/r
    Is = np.empty(B)
    for i in range(B):
        steps = 100
        I = sir_model(N, beta[i], r, steps, dt = 1)[1]
        if not int(I[-1]) == 0:
            steps = steps*2
            continue
        Is[i] = sum(I)
    return R0, Is

# %%
N = 10000
r = 2
beta = np.linspace(0.1, 4, 1000)
X = total_infected_for_r(beta, r, N)

# %%
plt.figure(figsize = (16, 9), dpi = 150)
plt.plot(X[0], X[1])
plt.xlabel("R0")
plt.ylabel("Sum of Infected")
plt.show()

# %% [markdown]
# ## Task 2

# %%
def symulate_epidemic(graph, probability, folder_name):
    
    nodes = list(graph.nodes())
    susceptible = nodes
    infected = [np.random.choice(susceptible)]
    susceptible.remove(infected[0])
    removed = []
    
    if os.path.exists(folder_name):
        shutil.rmtree(folder_name)
    os.makedirs(folder_name)
    
    set_pos = nx.spring_layout(graph)
    
    nodes_colors = ["blue"]*len(nodes)
    nodes_and_colors = dict(zip(nodes, nodes_colors))
    step = 0
    for i in infected:
        nodes_and_colors[i] = "red"
    for r in removed:
        nodes_and_colors[r] = "gray"
    plt.figure(figsize = (16, 9), dpi = 150)
    nx.draw(graph, node_color = list(dict(sorted(nodes_and_colors.items())).values()), pos=set_pos)
    plt.title(f'Step: {step}',fontsize=14)
    plt.savefig(f'{folder_name}/img_{step}.png', transparent = False, facecolor = 'white')
    plt.close()
    while len(infected) != 0:
        step += 1
        for i in infected:
            new_infected = infected
            for s in graph.neighbors(i):sss
                if s in susceptible and np.random.uniform() < probability:
                    susceptible.remove(s)
                    new_infected.append(s)
            new_infected.remove(i)
            removed.append(i)
        infected = new_infected
        for i in infected:
            nodes_and_colors[i] = "red"
        for r in removed:
            nodes_and_colors[r] = "gray"
        plt.figure(figsize = (16, 9), dpi = 150)
        nx.draw(graph, node_color = list(dict(sorted(nodes_and_colors.items())).values()), pos=set_pos)
        plt.title(f'Step: {step}',fontsize=14)
        plt.savefig(f'{folder_name}/img_{step}.png', transparent = False, facecolor = 'white')
        plt.close()

# %%
def random_graph(N, p):
    G = nx.Graph()
    for i in range(N):
        G.add_node(i)
    for node in G.nodes():
        for i in range(node + 1, N):
            if p >= np.random.uniform(0, 1):
                G.add_edge(node, i)
    return G

# %%
def watts_model(N, p):
    G = nx.Graph()
    G.add_node(0)
    G.add_node(1)
    G.add_edge(0, 1)
    for i in range(2, N):
        G.add_node(i)
        G.add_edge(i-1, i)
        G.add_edge(i-2, i)
    G.add_edge(N-1, 0)
    G.add_edge(N-1, 1)
    G.add_edge(N-2, 0)
    for edge in G.edges():
        if p >= np.random.uniform(0, 1):
            G.remove_edge(edge[0], edge[1])
            node = random.choice(list(G.nodes()))
            G.add_edge(edge[0], node)
    return G

# %%
def Barabasi_model(N, steps, links):
    G = nx.Graph()
    G.add_node(0)
    for i in range(1, N):
        G.add_node(i)
        G.add_edge(i-1, i)
    G.add_edge(N-1, 0)
    for i in range(1, steps + 1):
        nodes = random.sample(list(G.nodes()), k = links)
        G.add_node(N + i)
        for j in range(links):
            G.add_edge(N + i, nodes[j])
    return G

# %%
G = Barabasi_model(10, 5, 2)

# %%
symulate_epidemic(G, 0.8, "first")

# %%
X[2] = 'red'

# %%
X
# Out:
# {0: 'blue',
#  1: 'blue',
#  2: 'red',
#  3: 'blue',
#  4: 'blue',
#  5: 'blue',
#  6: 'blue',
#  7: 'blue',
#  8: 'blue',
#  11: 'blue',
#  12: 'blue',
#  13: 'blue',
#  14: 'blue',
#  15: 'blue'}

# %%
def si_model(N, beta, r, steps, dt = 1):
    S0 = N - 1
    I0 = 1
    S, I = [S0], [I0]
    for i in range(int(steps/dt) - 1):
        S.append(S[i] - (beta*S[i]*I[i]/N)*dt)
        I.append(I[i] + (beta*S[i]*I[i]/N - r*I[i])*dt)
    return S, I

# %%
def make_pngs(N, beta, r, steps, folder_name, gif_name, dt = 1):
    if os.path.exists(folder_name):
        shutil.rmtree(folder_name)
    os.makedirs(folder_name)
    if type(beta) == list:
        for i in range(len(beta)):
            X = sir_model(N, beta[i], r, steps, dt = 1)
            plt.figure(figsize = (16, 9), dpi = 150)
            plt.plot(X[0])
            plt.plot(X[1])
            plt.plot(X[2])
            plt.legend(["S: susceptible", "I: infected", "R: removed"])
            plt.title(f"SIR model for diffrfent beta and r = {r}")
            plt.savefig(f'{folder_name}/img_{i}.png', 
                        transparent = False,  
                        facecolor = 'white')
            plt.close()
    if type(r) == list:
        for i in range(len(r)):
            X = sir_model(N, beta, r[i], steps, dt = 1)
            plt.figure(figsize = (16, 9), dpi = 150)
            plt.plot(X[0])
            plt.plot(X[1])
            plt.plot(X[2])
            plt.legend(["S: susceptible", "I: infected", "R: removed"])
            plt.title(f"SIR model for diffrfent beta and r = {r}")
            plt.savefig(f'{folder_name}/img_{i}.png', 
                        transparent = False,  
                        facecolor = 'white')
            plt.close()

# %%
def make_gif(N, beta, r, steps, folder_name, gif_name, dt = 1):
    make_pngs(N, beta, r, steps, folder_name, gif_name, dt = 1)
    sorted_files = sorted(os.listdir(folder_name), key=lambda x: int(x.split('_')[1].split('.')[0]) if '_' in x else -1)
    images = []
    for filename in sorted_files:
        if filename.endswith('.png'):  
            filepath = os.path.join(folder_name, filename)
            image = imageio.v2.imread(filepath)
            images.append(image)
    imageio.mimsave(gif_name, images, format='gif', duration=0.01)

# %%
make_gif(N, list(np.linspace(0, 1, 100)), 0.5, 100, 'first', 'first1.gif')
